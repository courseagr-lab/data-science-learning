# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("../data/raw/po_late_delivery_dataset.csv")

df.head()
# Out:
#             po_id supplier_id              supplier_name supplier_country  \
# 0  PO-2025-002296     SUP-026        Supplier Generic 26        Indonesia
# 1  PO-2024-001711     SUP-008  Shenzhen Precision Metals      South Korea
# 2  PO-2024-002451     SUP-038        Supplier Generic 38            China
# 3  PO-2025-002269     SUP-036        Supplier Generic 36       Indonesia
# 4  PO-2024-001219     SUP-008  Shenzhen Precision Metals      South Korea
#
#   material_category material_criticality  order_date promised_delivery_date  \
# 0         Packaging               Medium  2025-02-10             2025-02-15
# 1         Component                  Low  2024-12-22             2025-01-13
# 2      Raw Material                  Low  2024-03-04             2024-03-19
# 3      Raw Material                 High  2025-03-21             2025-03-26
# 4               MRO                  Low  2024-10-09             2024-10-23
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   po_id                             2506 non-null   str
#  1   supplier_id                       2506 non-null   str
#  2   supplier_name                     2506 non-null   str
#  3   supplier_country                  2506 non-null   str
#  4   material_category                 2506 non-null   str
#  5   material_criticality              2506 non-null   str
#  6   order_date                        2506 non-null   str
#  7   promised_delivery_date            2506 non-null   str
#  8   quantity_ordered                  2506 non-null   int64
#  9   unit_price_usd                    2431 non-null   float64
#  10  order_value_usd                   2431 non-null   float64
#  11  payment_terms                     2469 non-null   str
# ...

# %%
df.describe()
# Out:
#        quantity_ordered  unit_price_usd  order_value_usd   distance_km  \
# count      2.506000e+03     2431.000000      2431.000000   2506.000000
# mean       2.905577e+03       16.659338     18815.054636   4281.112490
# std        3.600869e+04       16.820779     36028.579608   4025.598592
# min        1.900000e+01      -34.590000       187.520000    236.100000
# 25%        3.362500e+02        6.955000      3437.250000   1796.600000
# 50%        6.890000e+02       11.810000      8068.590000   3349.750000
# 75%        1.390000e+03       20.665000     19735.700000   5363.300000
# max        1.107163e+06      320.000000    595952.550000  19467.000000
#
#        supplier_lead_time_avg_days  supplier_otd_rate_historical_pct  \
# count                  2506.000000                       2456.000000
# mean                     15.821389                         71.618526
# std                       7.093030                         16.685183
# ...

# %% [markdown]
# ## Cek Missing Value

# %%
missing = df.isna().sum()
missing_0 = missing[missing > 0]
missing_pct = missing_0 / len(df) * 100
missing_df = pd.DataFrame({
    "Missing": missing_0,
    "missing %": missing_pct
})
print(missing_df)
# Out:
#                                   Missing  missing %
# unit_price_usd                         75   2.992817
# order_value_usd                        75   2.992817
# payment_terms                          37   1.476457
# supplier_otd_rate_historical_pct       50   1.995211

# %%
df.groupby(df['unit_price_usd'].isna())['material_category'].value_counts()
# Out:
# unit_price_usd  material_category
# False           Raw Material         829
#                 Component            755
#                 Packaging            485
#                 MRO                  362
# True            Raw Material          26
#                 Component             22
#                 Packaging             17
#                 MRO                   10
# Name: count, dtype: int64

# %% [markdown]
# ## Inkonsistensi Kategorikal

# %%
for col in df.columns:
    if df[col].dtype == object:
