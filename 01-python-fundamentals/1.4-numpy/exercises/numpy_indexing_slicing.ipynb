# %% [markdown]
# # 1. Indexing dasar
#
# Buat array 1D berisi 10 angka acak (np.arange(10, 101, 10)). Ambil elemen pertama, elemen terakhir (pakai negative index), dan elemen ke-5 dari belakang.

# %% [markdown]
# # 2. Slicing tabel
#
# Buat array 2D 4x5 berisi angka 1–20 (np.arange(1,21).reshape(4,5)). Lakukan:
# * Ambil 2 baris pertama, semua kolom
# * Ambil semua baris, 2 kolom terakhir
# * Ambil baris tengah (index 1-2) dan kolom tengah (index 1-3)

# %% [markdown]
# # 3. Simulasi split fitur & target
#
# Buat array 2D 5x4 (5 sampel, 4 kolom — anggap kolom terakhir adalah target/label). Pisahkan menjadi X (semua kolom kecuali terakhir) dan y (kolom terakhir saja) menggunakan slicing.

# %% [markdown]
# # 4. Buktikan konsep View vs Copy
#
# * Buat array original = np.arange(10)
# * Ambil slice_a = original[2:6] (tanpa .copy()), ubah salah satu elemennya, lalu cek apakah original ikut berubah
# * Ulangi dengan slice_b = original[2:6].copy(), ubah elemennya, cek original — pastikan tidak berubah
# * Tulis satu paragraf pendek: kapan kamu harus pakai .copy() dalam pekerjaan nyata?

# %% [markdown]
# # 5. Reverse & step
# Buat array 1D berisi 1-20. Ambil hanya angka genap menggunakan slicing dengan step (bukan boolean masking — itu materi modul 03). Lalu balik urutan array tersebut jadi dari besar ke kecil.
